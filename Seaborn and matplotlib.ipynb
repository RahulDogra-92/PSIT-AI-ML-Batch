# %% [markdown]
# # Errorbar graph in Python using Matplotlib

# %% [markdown]
# Error bars function used as graphical enhancement that visualizes the variability of the plotted data on a Cartesian graph. Error bars can be applied to graphs to provide an additional layer of detail on the presented data.

# %% [markdown]
# Error bars help you indicate estimated error or uncertainty to give a general sense of how precise a measurement is this is done through the use of markers drawn over the original graph and its data points.

# %% [markdown]
# Creating a Simple Graph.

# %%
# importing matplotlib
import matplotlib.pyplot as plt
 
# making a simple plot
x =[1, 2, 3, 4, 5, 6, 7]
y =[1, 2, 1, 2, 1, 2, 1]
 
# plotting graph
plt.plot(x, y)

# %% [markdown]
# Example 1: Adding Some error in y value.

# %%
import matplotlib.pyplot as plt
 
 
# making a simple plot
x =[1, 2, 3, 4, 5, 6, 7]
y =[1, 2, 1, 2, 1, 2, 1]
 
# creating error
y_error = 0.2
 
# plotting graph
plt.plot(x, y)
 
plt.errorbar(x, y,
             yerr = y_error,
             fmt ='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Example 2: Adding Some error in x value.

# %%
import matplotlib.pyplot as plt
 
# making a simple plot
x =[1, 2, 3, 4, 5, 6, 7]
y =[1, 2, 1, 2, 1, 2, 1]
 
# creating error
x_error = 0.5
 
# plotting graph
plt.plot(x, y)
plt.errorbar(x, y,
             xerr = x_error,
             fmt ='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Example 3: Adding error in x & y

# %%
# importing matplotlib
import matplotlib.pyplot as plt
 
 
# making a simple plot
x =[1, 2, 3, 4, 5, 6, 7]
y =[1, 2, 1, 2, 1, 2, 1]
 
# creating error
x_error = 0.5
y_error = 0.3
 
# plotting graph
plt.plot(x, y)
plt.errorbar(x, y,
             yerr = y_error,
             xerr = x_error,
             fmt ='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Plotting graph For IRIS Dataset Using Seaborn And Matplotlib

# %%
# !pip install matplotlib
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Iris.csv")
   
data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris = pd.read_csv("Iris.csv")
 
plt.plot(iris.Id, iris["SepalLengthCm"], "r--")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
iris.plot(kind ="scatter",
          x ='SepalLengthCm',
          y ='PetalLengthCm')
plt.grid()

# %%
import seaborn as sns
 
iris = sns.load_dataset('iris')
 
# style used as a theme of graph
# for example if we want black
# graph with grid then write "darkgrid"
sns.set_style("whitegrid")
 
# sepal_length, petal_length are iris
# feature data height used to define
# Height of graph whereas hue store the
# class of iris dataset.
sns.FacetGrid(iris, hue ="species",
              height = 6).map(plt.scatter,
                              'sepal_length',
                              'petal_length').add_legend()

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
ax=sns.stripplot(x='Species',y='SepalLengthCm',data=data,jitter=True,edgecolor='gray')

# %%
ax=sns.boxplot(x='Species',y='SepalLengthCm',data=data)
ax=sns.stripplot(x='Species',y='SepalLengthCm',data=data,jitter=True,edgecolor='gray')

# %%
sns.pairplot(data=iris,kind='scatter')

# %% [markdown]
# # Plotting heat map

# %%
plt.figure(figsize=(7,4))
sns.heatmap(iris.corr(),annot=True,cmap='summer')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Distribution plot

# %%
iris.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()
